# %% [markdown]
# <a href="https://colab.research.google.com/github/haiderzm/Helmet-Detection/blob/main/Helmet_Detection_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Mounting google drive in colab for data

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Cloning the ultralytics implementation of yolo_v5

# %%
# !git clone https://github.com/ultralytics/yolov5

# %% [markdown]
# ## Installing the requirements of yolov5 model

# %%
# !cd yolov5 && pip install -r requirements.txt

# %% [markdown]
# ## Import statements

# %%
import torch
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Loading the yolo_v5 model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# %%
model

# %% [markdown]
# ## Moving dataset.yaml file to the yolov5 directory

# %%
# !mv dataset.yaml /content/yolov5/

# %% [markdown]
# ## Training the yolo_v5 model on custom dataset

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 350 --data dataset.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=350, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-216-g856d4e5 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# Out:
# True
